# %%
import json
import os, sys
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('normalizedTextSimilarity.csv')
data.drop('Unnamed: 0',axis=1, inplace = True)

# %%
dicty = {"name":"Daylight","group":0},
# Out:
#           0         1         2         3         4         5         6  \
# 0  8.456386 -0.108410  0.140493 -0.135552 -0.171340 -0.021229 -0.266880
# 1  0.010038  5.939896 -0.128466  0.461158 -0.292087  0.015615 -0.201807
# 2  0.053262 -0.270751  8.513362 -0.330158 -0.306189 -0.408602 -0.232297
# 3 -0.087878  0.254172 -0.196497  8.302016 -0.037371 -0.017802 -0.149540
# 4 -0.033187 -0.225902 -0.080124  0.050866  8.310970  0.089302 -0.173060
#
#           7         8         9    ...           65        66        67  \
# 0 -0.093589 -0.137202 -0.066452    ...    -0.373437 -0.159321 -0.256600
# 1  0.268894 -0.158392  0.265914    ...    -0.304670 -0.138384 -0.181364
# 2 -0.314678 -0.079649 -0.367620    ...    -0.290743 -0.114829 -0.320726
# 3  0.040093 -0.043287  0.299915    ...    -0.038308 -0.136639 -0.173491
# 4  0.156636 -0.158392  0.352618    ...     0.766874  0.038710  0.087210
#
#          68        69        70        71        72        73        74
# ...
