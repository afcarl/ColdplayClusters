# %%
import os, sys
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataText = pd.read_csv('ColdplaySongs.csv')
names = map(lambda x: x[:-4], dataText['songs'])
sel = 75

# %%
from itertools import combinations

nodes = range(sel)
edges = combinations(nodes, 2)
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)#,weight = dataSim.iloc[edges[0][edges[1]])
nx.draw(G)

# %%
mapping = dict(zip(nodes,names[:sel]))

# %%
g = nx.DiGraph()
nodes = range(sel)
G.add_nodes_from(nodes)
for (u, v) in G.edges():
    if 
    
    g.add_edge(u,v,length=1 - dataSim[u][v])

# %%
nx.draw(g)

# %%
H=nx.relabel_nodes(g,mapping)

# %%
plt.figure(figsize=(40,40))
nx.draw(H,pos=nx.spring_layout(H),node_size = 20,alpha=0.8, style = 'dashed',with_labels = True)

# %%
dataSim = pd.read_csv('textSimilarity.csv')

# %%
dataSim.columns = map(lambda x: 'Song'+str(x),range(len(dataSim)))

# %%
from sklearn import preprocessing
dataSim = preprocessing.scale(dataSim)
dataSim =

# %%
data1 = pd.DataFrame(data = dataSim,columns = range(75))

# %%
data1.to_csv("normalizedTextSimilarity.csv")

# %%
data1
# Out:
#           0         1         2         3         4         5         6   \
# 0   8.456386 -0.108410  0.140493 -0.135552 -0.171340 -0.021229 -0.266880
# 1   0.010038  5.939896 -0.128466  0.461158 -0.292087  0.015615 -0.201807
# 2   0.053262 -0.270751  8.513362 -0.330158 -0.306189 -0.408602 -0.232297
# 3  -0.087878  0.254172 -0.196497  8.302016 -0.037371 -0.017802 -0.149540
# 4  -0.033187 -0.225902 -0.080124  0.050866  8.310970  0.089302 -0.173060
# 5   0.118539 -0.003552 -0.191838  0.071772  0.093953  8.077536 -0.031068
# 6  -0.279035 -0.268225 -0.155713 -0.206983 -0.322054 -0.175458  8.359567
# 7  -0.096700  0.082356 -0.235698 -0.008370  0.022562 -0.169461  0.275567
# 8  -0.343430 -0.376873 -0.196760 -0.294094 -0.502735 -0.490772 -0.351640
# 9   0.017095  0.143629 -0.206956  0.343559  0.313414  0.149280 -0.224456
# 10  0.068258  0.286388 -0.147803 -0.281027 -0.167814  0.751633 -0.219230
# 11 -0.198144 -0.184212 -0.051997 -0.157329 -0.169577 -0.295415 -0.232297
# ...

# %%
np.max(dataSim)
# Out:
# 8.5859045429191791
